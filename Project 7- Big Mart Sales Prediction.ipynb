# %% [markdown]
# # Aim: The aim is to build a predictive model and find out the sales of each product at a particular store.

# %% [markdown]
# ## Problem Statment

# %% [markdown]
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and find out the sales of each product at a particular store.
#
# Using this model, BigMart will try to understand the properties of products and stores which play a key role in increasing the sales of their products.

# %% [markdown]
# #### Variable Description
#
# ItemIdentifier ---- Unique product ID
# ItemWeight ---- Weight of product
# ItemFatContent ---- Whether the product is low fat or not
# ItemVisibility ---- The % of the total display area of all products in a store allocated to the particular product
# ItemType ---- The category to which the product belongs
# ItemMRP ---- Maximum Retail Price (list price) of the product
# OutletIdentifier ---- Unique store ID
# OutletEstablishmentYear ---- The year in which the store was established
# OutletSize ---- The size of the store in terms of ground area covered
# OutletLocationType ---- The type of city in which the store is located
# OutletType ---- Whether the outlet is just a grocery store or some sort of supermarket
# ItemOutletSales ---- sales of the product in t particular store. This is the outcome variable to be predicted.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd 

import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mode
# %matplotlib inline

# %% [markdown]
# #### Loading data

# %%
train= pd.read_csv(r'D:\python\dataset1-master\bigdatamart_rep-master\bigdatamart_Train.csv')
test= pd.read_csv(r'D:\python\dataset1-master\bigdatamart_rep-master\bigdatamart_Test.csv')

# %% [markdown]
# train is our training dataset.
# test is our testing dataset.

# %% [markdown]
# ## Data Analysis

# %%
train.shape
# Out:
# (8523, 12)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# Train data having 8523 Rows and 12 columns
# Categorical Data
# -Item_Identifier
# -Item_Fat_Content
# -Item_Type
# -Outlet_Identifier
# -Outlet_Size
# -Outlet_Location_Type
# -Outlet_Type
#
# Other are continues

# %%
test.shape
# Out:
# (5681, 11)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %% [markdown]
# Test data having 5681 Rows and 11 columns
# Categorical Data
# -Item_Identifier
# -Item_Fat_Content
# -Item_Type
# -Outlet_Identifier
# -Outlet_Size
# -Outlet_Location_Type
# -Outlet_Type
#
# Other are continues

# %% [markdown]
# # Data Visualization

# %% [markdown]
# #### Univariate analysis of Train Data

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(10,7))
sns.distplot(train['Item_Outlet_Sales'], color='red',kde_kws={"color": "k", "lw": 5, "label": "KDE"})
plt.title('Target Variable', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see the sale desity of range 0-2500  is higher,
# Max sale is around 14000,
# Data is having outliers.

# %%
plt.figure(figsize=(10,7))
sns.distplot(train['Item_MRP'], color='red',kde_kws={"color": "k", "lw": 5, "label": "KDE"})
plt.title('Item_MRP', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see Max MRP for a product is slightlty higher than 250 and minimum MRP is greater than 25.
# Most of the products are in range of 75- 200

# %%
plt.figure(figsize=(10,7))
sns.distplot(train['Item_Visibility'], color='red',kde_kws={"color": "k", "lw": 5, "label": "KDE"})
plt.title('Item_Visibility', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see min value of visiblity is 0, and many product having visiblity 0, which is not possible.
# we will treat this later
# Max density of product having visiblity less than 0.10,
# Desnsity of product having visiblity more than 0.20 are less in number, and max visiblity is around 0.35
# We can see outliers are also presenst.

# %%
plt.figure(figsize=(10,7))
sns.distplot(train['Item_Weight'], color='red',kde_kws={"color": "k", "lw": 5, "label": "KDE"})
plt.title('Item_Weight', fontsize=15)
plt.show()

# %% [markdown]
# Item_Weight is having range between 5 to 20.
# Item_Weight between 6-10 having higher Density.

# %%
plt.figure(figsize=(10,7))
sns.countplot(train['Item_Fat_Content'])
plt.title('Item_Fat_Content', fontsize=15)
plt.show()

# %% [markdown]
# Here we can number of Low Fat content products are higher than the regular.
# One more thing to observe that LF and low fat are same catagory with difrent notaion, reg used for regular.
# So we can see products having only Two catagory, which is Low Fat and Regular.
# we will deal with his later in the data cleaning process

# %%
plt.figure(figsize=(15,7))
sns.countplot(train['Item_Type'], )
plt.title('Item_Type', fontsize=15)
locs, labels = plt.xticks()
plt.setp(labels, rotation=80)
plt.show()

# %% [markdown]
# Here we can see Fruits and Vegitables having max count and Seafood is having minmum count.
# we can say Fruits_Vegitables and Snacks Foods are having good sale as compare to other.

# %%
plt.figure(figsize=(10,7))
sns.countplot(train['Outlet_Size'], )
plt.title('Outlet_Size', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see Most of the outlet are Medium in Size.
# High_Size outlet are less in number.

# %%
plt.figure(figsize=(10,7))
sns.countplot(train['Outlet_Location_Type'], )
plt.title('Outlet_Location_Type', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see max outlets are present in Tier 3 city.
# Number of outlet in Tier 1 are less.

# %%
plt.figure(figsize=(10,7))
sns.countplot(train['Outlet_Type'], )
plt.title('Outlet_Type', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see Supermarket type 1 are maximun in m=numbers.
# Other are very less in number as compar to Type 1.
# we can see most of the product are sold from Supermarket type 1.

# %% [markdown]
# #### Bivariate Analysis

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=train, x='Item_Weight', y='Item_Outlet_Sales', hue='Item_Weight')
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# Here we can see ItemPWeight is not having much effect on sale of product.
# each weight category having almost same sales pattern.

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=train, x='Item_Visibility', y='Item_Outlet_Sales',hue='Item_Visibility')
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# Here we can see most of the item within visiblity 0.20 are having good sale.
# sales for visiblity more than 0.20 is very less
# more than 7000 items having visiblity 0 , whisch is not possible.

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=train, x='Item_Type', y='Item_Outlet_Sales')
locs, labels = plt.xticks()
plt.setp(labels, rotation=80)
plt.show()

# %% [markdown]
# Here we can see Item_type is having less impact on sales.

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=train, x='Item_MRP', y='Item_Outlet_Sales')
locs, labels = plt.xticks()
plt.setp(labels, rotation=80)
plt.show()

# %% [markdown]
# Here we can see positive relationship. As the MRP increasing, Item_outlet_sales also increasing.

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=train, x='Outlet_Identifier', y='Item_Outlet_Sales')
locs, labels = plt.xticks()
plt.setp(labels, rotation=80)
plt.show()

# %% [markdown]
# we can see for OUT027 we havr hiighest Item_outlate_sales.

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=train, x='Outlet_Size', y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# Here we casn see sale Sales of medium Size store is high.

# %% [markdown]
# Lets merge both training and testing dataset, so that we can perform all the step of data preprocessing in one go.

# %%
train['source'] = 'train'
test['source'] = 'test'
test['Item_Outlet_Sales'] = 0
data = pd.concat([train, test],  sort=False)
print(train.shape, test.shape, data.shape)
# Out:
# (8523, 13) (5681, 13) (14204, 13)

# %% [markdown]
# Here we have set test ['Item_Outlet_Sales'] = 0, so that our data should have same dimension, after all cleaning steps we will drop that from test dataset.

# %%
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales source
# 0  Supermarket Type1          3735.1380  train
# 1  Supermarket Type2           443.4228  train
# 2  Supermarket Type1          2097.2700  train
# 3      Grocery Store           732.3800  train
# 4  Supermarket Type1           994.7052  train
# 5  Supermarket Type2           556.6088  train
# 6  Supermarket Type1           343.5528  train
# 7  Supermarket Type3          4022.7636  train
# 8  Supermarket Type1          1076.5986  train
# 9  Supermarket Type1          4710.5350  train

# %% [markdown]
# #### Checking Null Values

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# source                          0
# dtype: int64

# %% [markdown]
# We can see null values are present in two columns:
# Item_Weight - 2439
# Outlet_Size - 4016

# %% [markdown]
# #### Data cleaning and imputing

# %% [markdown]
# ###### Item_Weight
# Item_Weight is an contineus value.
# We can use mean of the Item_Weight to replace the Nan values.

# %%
data['Item_Weight'].fillna(value=data['Item_Weight'].mean(), inplace= True)

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# source                          0
# dtype: int64

# %% [markdown]
# Nan values for Item_Weight filled using mean of Item_Weight column.

# %% [markdown]
# #### Outlet_Size
# Outlet_Size is a categorical value, we can replace it using mode.

# %%
Mode_of_Outlet_Size= data.pivot_table(values= 'Outlet_Size', columns='Outlet_Type', aggfunc=(lambda x: x.mode()[0]))

# %%
Mode_of_Outlet_Size
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %% [markdown]
# We calculated the Mode on the basis of Outlet_type

# %%
missing_values=data['Outlet_Size'].isnull()

# %%
data.loc[missing_values,'Outlet_Size'] = data.loc[missing_values,'Outlet_Type'].apply(lambda x: Mode_of_Outlet_Size[x])
print (sum(data['Outlet_Size'].isnull()))
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# source                       0
# dtype: int64

# %% [markdown]
# ###### Now data is not having any Null values.

# %%
data.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000          Low Fat         0.016047
# 1            DRC01     5.920000          Regular         0.019278
# 2            FDN15    17.500000          Low Fat         0.016760
# 3            FDX07    19.200000          Regular         0.000000
# 4            NCD19     8.930000          Low Fat         0.000000
# 5            FDP36    10.395000          Regular         0.000000
# 6            FDO10    13.650000          Regular         0.012741
# 7            FDP10    12.792854          Low Fat         0.127470
# 8            FDH17    16.200000          Regular         0.016687
# 9            FDU28    19.200000          Regular         0.094450
# 10           FDY07    11.800000          Low Fat         0.000000
# 11           FDA03    18.500000          Regular         0.045464
# 12           FDX32    15.100000          Regular         0.100014
# 13           FDS46    17.600000          Regular         0.047257
# 14           FDF32    16.350000          Low Fat         0.068024
# 15           FDP49     9.000000          Regular         0.069089
# 16           NCB42    11.800000          Low Fat         0.008596
# 17           FDP49     9.000000          Regular         0.069196
# 18           DRI11    12.792854          Low Fat         0.034238
# 19           FDU02    13.350000          Low Fat         0.102492
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 1             Soft Drinks   48.2692            OUT018
# 2                    Meat  141.6180            OUT049
# 3   Fruits and Vegetables  182.0950            OUT010
# 4               Household   53.8614            OUT013
# 5            Baking Goods   51.4008            OUT018
# 6             Snack Foods   57.6588            OUT013
# 7             Snack Foods  107.7622            OUT027
# 8            Frozen Foods   96.9726            OUT045
# 9            Frozen Foods  187.8214            OUT017
# 10  Fruits and Vegetables   45.5402            OUT049
# 11                  Dairy  144.1102            OUT046
# 12  Fruits and Vegetables  145.4786            OUT049
# 13            Snack Foods  119.6782            OUT046
# 14  Fruits and Vegetables  196.4426            OUT013
# 15              Breakfast   56.3614            OUT046
# 16     Health and Hygiene  115.3492            OUT018
# 17              Breakfast   54.3614            OUT049
# 18            Hard Drinks  113.2834            OUT027
# 19                  Dairy  230.5352            OUT035
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                        1999      Medium               Tier 1
# 1                        2009      Medium               Tier 3
# 2                        1999      Medium               Tier 1
# 3                        1998       Small               Tier 3
# 4                        1987        High               Tier 3
# 5                        2009      Medium               Tier 3
# 6                        1987        High               Tier 3
# 7                        1985      Medium               Tier 3
# 8                        2002       Small               Tier 2
# 9                        2007       Small               Tier 2
# 10                       1999      Medium               Tier 1
# 11                       1997       Small               Tier 1
# 12                       1999      Medium               Tier 1
# 13                       1997       Small               Tier 1
# 14                       1987        High               Tier 3
# 15                       1997       Small               Tier 1
# 16                       2009      Medium               Tier 3
# 17                       1999      Medium               Tier 1
# 18                       1985      Medium               Tier 3
# 19                       2004       Small               Tier 2
#
#           Outlet_Type  Item_Outlet_Sales source
# 0   Supermarket Type1          3735.1380  train
# 1   Supermarket Type2           443.4228  train
# 2   Supermarket Type1          2097.2700  train
# 3       Grocery Store           732.3800  train
# 4   Supermarket Type1           994.7052  train
# 5   Supermarket Type2           556.6088  train
# 6   Supermarket Type1           343.5528  train
# 7   Supermarket Type3          4022.7636  train
# 8   Supermarket Type1          1076.5986  train
# 9   Supermarket Type1          4710.5350  train
# 10  Supermarket Type1          1516.0266  train
# 11  Supermarket Type1          2187.1530  train
# 12  Supermarket Type1          1589.2646  train
# 13  Supermarket Type1          2145.2076  train
# 14  Supermarket Type1          1977.4260  train
# 15  Supermarket Type1          1547.3192  train
# 16  Supermarket Type2          1621.8888  train
# 17  Supermarket Type1           718.3982  train
# 18  Supermarket Type3          2303.6680  train
# 19  Supermarket Type1          2748.4224  train

# %%
categorial_features = data.select_dtypes(include=[np.object])
categorial_features.head()
# Out:
#   Item_Identifier Item_Fat_Content              Item_Type Outlet_Identifier  \
# 0           FDA15          Low Fat                  Dairy            OUT049
# 1           DRC01          Regular            Soft Drinks            OUT018
# 2           FDN15          Low Fat                   Meat            OUT049
# 3           FDX07          Regular  Fruits and Vegetables            OUT010
# 4           NCD19          Low Fat              Household            OUT013
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type source
# 0      Medium               Tier 1  Supermarket Type1  train
# 1      Medium               Tier 3  Supermarket Type2  train
# 2      Medium               Tier 1  Supermarket Type1  train
# 3       Small               Tier 3      Grocery Store  train
# 4        High               Tier 3  Supermarket Type1  train

# %%
numerical_features = data.select_dtypes(include=[np.number])
numerical_features.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           732.3800
# 4           994.7052

# %% [markdown]
# we have devided data into categorial_features and numerical_features.

# %% [markdown]
# Lets check  every columns one by one.

# %%
data['Item_Identifier'].unique()
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
for col in categorial_features:
    print('\n%s column: '%col)
    print(data[col].value_counts())
    print('*'*20)
# Out:
# Item_Identifier column:
# NCF30    10
# NCH18    10
# FDV21    10
# FDA38    10
# FDS13    10
#          ..
# NCL42     7
# FDI46     7
# DRN11     7
# FDM10     7
# FDR51     7
# Name: Item_Identifier, Length: 1559, dtype: int64
# ********************
#
# Item_Fat_Content column:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64
# ********************
#
# Item_Type column:
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64
# ********************
#
# Outlet_Identifier column:
# OUT027    1559
# OUT013    1553
# OUT046    1550
# OUT035    1550
# OUT049    1550
# OUT045    1548
# OUT018    1546
# OUT017    1543
# OUT010     925
# OUT019     880
# Name: Outlet_Identifier, dtype: int64
# ********************
#
# Outlet_Size column:
# Small     7996
# Medium    4655
# High      1553
# Name: Outlet_Size, dtype: int64
# ********************
#
# Outlet_Location_Type column:
# Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64
# ********************
#
# Outlet_Type column:
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64
# ********************
#
# source column:
# train    8523
# test     5681
# Name: source, dtype: int64
# ********************

# %% [markdown]
# ###### Item_Identifier columns:
#  we have 1559 products. If we encode 1559 values will create no sense. But we can see first two alphabet its gives specofic indication like FD for Food , DR for Drinks and NC for Non Consumables.
# so we can encode Identifier in 3 catagories.

# %% [markdown]
# ###### Item_Fat_Content:
# Here we have 5 catagories Low Fat, Regular, LF, reg ,low fat . Here LF , low fat and Low fat are same so we can combine them to make them one, and Regular , reg are also same  , we will make this one catagory.

# %% [markdown]
# ###### For columns Item_Type,  Outlet_Identifier,  Outlet_Size,   Outlet_Location_Type  and Outlet_Type   data not havig error.

# %% [markdown]
# ##### Item_Visibility
# It has a min value of zero. This makes no practical sense because when a product is being sold in a store, the visibility cannot be 0.

# %% [markdown]
# ##### Outlet_Establishment_Years
# vary from 1985 to 2009. The values might not be apt in this form. Rather, if we can convert them to how old the particular store is, it should have a better impact on sales.

# %% [markdown]
# ###### Categorizing the  Item_Identifier columns as FD, DR and NC

# %%
data.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales source
# 0               Tier 1  Supermarket Type1          3735.1380  train
# 1               Tier 3  Supermarket Type2           443.4228  train

# %%
#Get the first two characters of the ID column.
data['Item_type']=data['Item_Identifier'].apply(lambda x: x[0:2])

# %%
#Mapping the values
data['Item_type']=data['Item_type'].map({'FD':'Food Product', 'DR':'Drinks',  'NC':'Non Consumable'})
data['Item_type'].value_counts()
# Out:
# Food Product      10201
# Non Consumable     2686
# Drinks             1317
# Name: Item_type, dtype: int64

# %% [markdown]
# ##### Correction in Item_Fat_Content: Categorizing into Low Fat and Regular

# %%
print('Original Categories:')
print(data['Item_Fat_Content'].value_counts())

print('\nModified Categories:')

data['Item_Fat_Content'] = data['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular', 'low fat':'Low Fat'})
                                                             
print(data['Item_Fat_Content'].value_counts())
# Out:
# Original Categories:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64
#
# Modified Categories:
# Low Fat    9185
# Regular    5019
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# ##### Item_Visibility
# It has a min value of zero. This makes no practical sense because when a product is being sold in a store, the visibility cannot be 0.

# %%
data[data['Item_Visibility']== 0]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07    19.200000          Regular              0.0
# 4              NCD19     8.930000          Low Fat              0.0
# 5              FDP36    10.395000          Regular              0.0
# 10             FDY07    11.800000          Low Fat              0.0
# 32             FDP33    18.700000          Low Fat              0.0
# ...              ...          ...              ...              ...
# 5643           FDQ19    12.792854          Regular              0.0
# 5648           FDK26    12.792854          Regular              0.0
# 5654           FDQ57     7.275000          Low Fat              0.0
# 5661           DRG37    12.792854          Low Fat              0.0
# 5679           FDJ26    15.300000          Regular              0.0
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# 5              Baking Goods   51.4008            OUT018
# 10    Fruits and Vegetables   45.5402            OUT049
# 32              Snack Foods  256.6672            OUT018
# ...                     ...       ...               ...
# 5643  Fruits and Vegetables  244.3512            OUT019
# 5648                 Canned  187.5240            OUT027
# 5654            Snack Foods  144.5760            OUT013
# 5661            Soft Drinks  155.7972            OUT027
# 5679                 Canned  214.6218            OUT017
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                          1998       Small               Tier 3
# 4                          1987        High               Tier 3
# 5                          2009      Medium               Tier 3
# 10                         1999      Medium               Tier 1
# 32                         2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 5643                       1985       Small               Tier 1
# 5648                       1985      Medium               Tier 3
# 5654                       1987        High               Tier 3
# 5661                       1985      Medium               Tier 3
# 5679                       2007       Small               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales source       Item_type
# 3         Grocery Store           732.3800  train    Food Product
# 4     Supermarket Type1           994.7052  train  Non Consumable
# 5     Supermarket Type2           556.6088  train    Food Product
# 10    Supermarket Type1          1516.0266  train    Food Product
# 32    Supermarket Type2          3068.0064  train    Food Product
# ...                 ...                ...    ...             ...
# 5643      Grocery Store             0.0000   test    Food Product
# 5648  Supermarket Type3             0.0000   test    Food Product
# 5654  Supermarket Type1             0.0000   test    Food Product
# 5661  Supermarket Type3             0.0000   test          Drinks
# 5679  Supermarket Type1             0.0000   test    Food Product
#
# [879 rows x 14 columns]

# %% [markdown]
# ###### 879 rows of   Item_Visibility are having zero value,  We cannot drop thses row

# %%
Item_Visibility_mean=data['Item_Visibility'].mean()

# %%
data['Item_Visibility'] = data['Item_Visibility'].replace({0:Item_Visibility_mean})

# %%
(data['Item_Visibility']== 0).sum()
# Out:
# 0

# %% [markdown]
# #### Outlet_Establishment_Years

# %%
data['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    2439
# 1987    1553
# 2004    1550
# 1997    1550
# 1999    1550
# 2002    1548
# 2009    1546
# 2007    1543
# 1998     925
# Name: Outlet_Establishment_Year, dtype: int64

# %% [markdown]
# We have Outlet_Establishment_Year range from 1985 to 2009.
# we will calculate years_of_Opertaion as 2009- Outlet_Establishment_Year

# %%
data['Years_of_Opertaion']=2009-data['Outlet_Establishment_Year']

# %%
data.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.065953
# 4           NCD19         8.93          Low Fat         0.065953
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales source       Item_type  \
# 0  Supermarket Type1          3735.1380  train    Food Product
# 1  Supermarket Type2           443.4228  train          Drinks
# 2  Supermarket Type1          2097.2700  train    Food Product
# 3      Grocery Store           732.3800  train    Food Product
# 4  Supermarket Type1           994.7052  train  Non Consumable
#
#    Years_of_Opertaion
# 0                  10
# 1                   0
# 2                  10
# 3                  11
# 4                  22

# %% [markdown]
# Lets drop columns for which we have created New columns.

# %%
data.drop(['Item_Identifier','Outlet_Establishment_Year'], axis=1, inplace = True )

# %%
#We are droping Outlet_Identifier  also, it is not having relevent contribution.
data.drop(['Outlet_Identifier'],axis=1, inplace = True)

# %%
data .head(3)
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP  \
# 0         9.30          Low Fat         0.016047        Dairy  249.8092
# 1         5.92          Regular         0.019278  Soft Drinks   48.2692
# 2        17.50          Low Fat         0.016760         Meat  141.6180
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700
#
#   source     Item_type  Years_of_Opertaion
# 0  train  Food Product                  10
# 1  train        Drinks                   0
# 2  train  Food Product                  10

# %% [markdown]
# #### Encoding Categorical Features:

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

col= ['Item_Fat_Content','Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type','Item_type']
for i in col:
    data[i]=le.fit_transform(data[ i ])

# %% [markdown]
# ### Dividing Training and Testing data

# %%
#Divide into test and train:
train = data.loc[data['source']=="train"]
test = data.loc[data['source']=="test"]

#Drop unnecessary columns:
test.drop(['Item_Outlet_Sales','source'],axis=1,inplace=True)
train.drop(['source'],axis=1,inplace=True)

# %%
train.shape
# Out:
# (8523, 11)

# %%
test.shape
# Out:
# (5681, 10)

# %%
train.corr()
# Out:
#                       Item_Weight  Item_Fat_Content  Item_Visibility  \
# Item_Weight              1.000000         -0.021142        -0.018001
# Item_Fat_Content        -0.021142          1.000000         0.049914
# Item_Visibility         -0.018001          0.049914         1.000000
# Item_Type                0.028022         -0.139434        -0.036003
# Item_MRP                 0.024806          0.006063        -0.005248
# Outlet_Size             -0.013747         -0.001262         0.097536
# Outlet_Location_Type     0.003552         -0.001598        -0.027864
# Outlet_Type             -0.002932          0.002199        -0.179611
# Item_Outlet_Sales        0.011083          0.018719        -0.134141
# Item_type                0.063190         -0.166111        -0.046272
# Years_of_Opertaion       0.004267         -0.003151         0.078356
#
#                       Item_Type  Item_MRP  Outlet_Size  Outlet_Location_Type  \
# Item_Weight            0.028022  0.024806    -0.013747              0.003552
# Item_Fat_Content      -0.139434  0.006063    -0.001262             -0.001598
# Item_Visibility       -0.036003 -0.005248     0.097536             -0.027864
# Item_Type              1.000000  0.032651    -0.000218              0.003084
# Item_MRP               0.032651  1.000000     0.000872              0.000232
# Outlet_Size           -0.000218  0.000872     1.000000             -0.480075
# Outlet_Location_Type   0.003084  0.000232    -0.480075              1.000000
# Outlet_Type            0.003053 -0.001975    -0.401373              0.467219
# Item_Outlet_Sales      0.017048  0.567574    -0.162753              0.089367
# Item_type              0.007456  0.032517    -0.001276              0.007661
# Years_of_Opertaion    -0.004970 -0.005020    -0.425534              0.089216
#
#                       Outlet_Type  Item_Outlet_Sales  Item_type  \
# Item_Weight             -0.002932           0.011083   0.063190
# Item_Fat_Content         0.002199           0.018719  -0.166111
# Item_Visibility         -0.179611          -0.134141  -0.046272
# Item_Type                0.003053           0.017048   0.007456
# Item_MRP                -0.001975           0.567574   0.032517
# Outlet_Size             -0.401373          -0.162753  -0.001276
# Outlet_Location_Type     0.467219           0.089367   0.007661
# Outlet_Type              1.000000           0.401522   0.001136
# Item_Outlet_Sales        0.401522           1.000000   0.011236
# Item_type                0.001136           0.011236   1.000000
# Years_of_Opertaion       0.122304           0.049135   0.008551
#
#                       Years_of_Opertaion
# Item_Weight                     0.004267
# Item_Fat_Content               -0.003151
# Item_Visibility                 0.078356
# Item_Type                      -0.004970
# Item_MRP                       -0.005020
# Outlet_Size                    -0.425534
# Outlet_Location_Type            0.089216
# Outlet_Type                     0.122304
# Item_Outlet_Sales               0.049135
# Item_type                       0.008551
# Years_of_Opertaion              1.000000

# %%
plt.figure(figsize=(15, 7))

sns.heatmap(train.corr(),annot= True,linewidths=1,linecolor='black',fmt=' .2f' )
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking the columns which are positively and negatively correlated with the target.

# %%
plt.figure(figsize=(20,7))
train.corr()['Item_Outlet_Sales'].sort_values(ascending=False).drop(['Item_Outlet_Sales']).plot(kind='bar',color='c')
plt.xlabel('Feature', fontsize=14)
plt.ylabel('Columns with target name', fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# Here we can see Item_visiblity and Outlet_size having negative corellation and other having Positive correlation.

# %% [markdown]
# ### Checking outliers:
#
# We will check outliers for contineous colums, as catagorical data not having any outliers.

# %%
train['Item_Weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
train['Item_Visibility'].plot.box()
# Out:
# <AxesSubplot:>

# %%
train['Item_MRP'].plot.box()
# Out:
# <AxesSubplot:>

# %%
train['Item_Outlet_Sales'].plot.box()
# Out:
# <AxesSubplot:>

# %%
train['Years_of_Opertaion'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see only two colums "Years_of_Opertaion" and "Item_Visibility"  having Outliers.

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z= np.abs(zscore(train))
z
# Out:
# array([[0.83922588, 0.73814723, 1.11110934, ..., 0.910601  , 0.17979501,
#         0.13954076],
#        [1.63904672, 1.35474328, 1.04482003, ..., 1.01844035, 2.09528612,
#         1.33410274],
#        [1.10116786, 0.73814723, 1.09648522, ..., 0.04923754, 0.17979501,
#         0.13954076],
#        ...,
#        [0.53160248, 0.73814723, 0.71843133, ..., 0.57909963, 1.73569609,
#         0.73682175],
#        [1.33378966, 1.35474328, 1.53916558, ..., 0.19672492, 0.17979501,
#         1.33410274],
#        [0.46225773, 0.73814723, 0.51957848, ..., 0.82959407, 2.09528612,
#         0.09937163]])

# %%
df=train[(z<3).all(axis=1)]
print(train.shape)
print(df.shape)
# Out:
# (8523, 11)
# (8334, 11)

# %% [markdown]
# ### Removing Skweness

# %%
train.skew()
# Out:
# Item_Weight             0.098453
# Item_Fat_Content        0.616705
# Item_Visibility         1.287478
# Item_Type               0.101655
# Item_MRP                0.127202
# Outlet_Size            -0.861866
# Outlet_Location_Type   -0.209093
# Outlet_Type             0.927438
# Item_Outlet_Sales       1.177531
# Item_type               0.114510
# Years_of_Opertaion      0.396641
# dtype: float64

# %% [markdown]
# Here we are considring skewness only for contineous data and only for Feature column.
# Here Item_Visibility is the only colum having Skewness.

# %%
train['Item_Visibility'] = np.log( train['Item_Visibility'] )

# %%
train.skew()
# Out:
# Item_Weight             0.098453
# Item_Fat_Content        0.616705
# Item_Visibility        -0.484458
# Item_Type               0.101655
# Item_MRP                0.127202
# Outlet_Size            -0.861866
# Outlet_Location_Type   -0.209093
# Outlet_Type             0.927438
# Item_Outlet_Sales       1.177531
# Item_type               0.114510
# Years_of_Opertaion      0.396641
# dtype: float64

# %% [markdown]
# ### Scaling the data Using StandardScaler.

# %%
# Dividing into Feature and Target data
x=train.drop(['Item_Outlet_Sales'],axis=1)
y=train['Item_Outlet_Sales']

# %%
x.shape
# Out:
# (8523, 10)

# %%
y.shape
# Out:
# (8523,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
SDC=StandardScaler()
x=SDC.fit_transform(x)

# %%
x
# Out:
# array([[-0.83922588, -0.73814723, -1.59419711, ..., -0.25265831,
#         -0.17979501, -0.13954076],
#        [-1.63904672,  1.35474328, -1.35429802, ...,  1.00297245,
#         -2.09528612, -1.33410274],
#        [ 1.10116786, -0.73814723, -1.53736093, ..., -0.25265831,
#         -0.17979501, -0.13954076],
#        ...,
#        [-0.53160248, -0.73814723, -0.56741182, ..., -0.25265831,
#          1.73569609, -0.73682175],
#        [-1.33378966,  1.35474328,  1.286544  , ...,  1.00297245,
#         -0.17979501, -1.33410274],
#        [ 0.46225773, -0.73814723, -0.24922318, ..., -0.25265831,
#         -2.09528612,  0.09937163]])

# %% [markdown]
# Here we are not checking Multicolinearity as most of the columns are categorical

# %% [markdown]
# # Model Design

# %%
from sklearn.linear_model import LinearRegression

from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.neighbors import KNeighborsRegressor

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %% [markdown]
# # 1.LinearRegression

# %%
lr=LinearRegression()
for i in range(0, 100):
    x_train, x_test, y_train, y_test= train_test_split(x,y,random_state= i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train= lr.predict(x_train)
    pred_test= lr.predict(x_test)
    print(f"At Random Stat {i}, the training accuracy is:{r2_score(y_train,pred_train)}")
    print(f"At Random Stat {i}, the testing accuracy is:{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At Random Stat 0, the training accuracy is:0.4991502658172362
# At Random Stat 0, the testing accuracy is:0.5058189625465668
#
#
# At Random Stat 1, the training accuracy is:0.5005694329549548
# At Random Stat 1, the testing accuracy is:0.49975865382192186
#
#
# At Random Stat 2, the training accuracy is:0.5044479230826947
# At Random Stat 2, the testing accuracy is:0.48454074225521393
#
#
# At Random Stat 3, the training accuracy is:0.49139639718056205
# At Random Stat 3, the testing accuracy is:0.5357882307994404
#
#
# At Random Stat 4, the training accuracy is:0.5021182827226176
# At Random Stat 4, the testing accuracy is:0.49237544594168114
#
#
# At Random Stat 5, the training accuracy is:0.5032419824505869
# At Random Stat 5, the testing accuracy is:0.4894348944000336
#
#
# At Random Stat 6, the training accuracy is:0.49993794951008896
# At Random Stat 6, the testing accuracy is:0.501727814417557
#
#
# At Random Stat 7, the training accuracy is:0.5042034186295214
# At Random Stat 7, the testing accuracy is:0.48670263563624305
#
#
# At Random Stat 8, the training accuracy is:0.4973343708610807
# At Random Stat 8, the testing accuracy is:0.5107436350756778
#
#
# At Random Stat 9, the training accuracy is:0.501114583176272
# At Random Stat 9, the testing accuracy is:0.4979123171613512
#
#
# At Random Stat 10, the training accuracy is:0.49730465695168924
# At Random Stat 10, the testing accuracy is:0.5127608467462377
#
#
# At Random Stat 11, the training accuracy is:0.5073119904959349
# At Random Stat 11, the testing accuracy is:0.47275775671881615
#
#
# At Random Stat 12, the training accuracy is:0.49809397488074403
# At Random Stat 12, the testing accuracy is:0.5099857967673872
#
#
# At Random Stat 13, the training accuracy is:0.5020190383282725
# At Random Stat 13, the testing accuracy is:0.4939492315892686
#
#
# At Random Stat 14, the training accuracy is:0.5004023191720608
# At Random Stat 14, the testing accuracy is:0.5010856796085958
#
#
# At Random Stat 15, the training accuracy is:0.49649872351725755
# At Random Stat 15, the testing accuracy is:0.5136972490231471
#
#
# At Random Stat 16, the training accuracy is:0.5011357868392486
# At Random Stat 16, the testing accuracy is:0.49650119092592104
#
#
# At Random Stat 17, the training accuracy is:0.49833747219429414
# At Random Stat 17, the testing accuracy is:0.5093073283720584
#
#
# At Random Stat 18, the training accuracy is:0.502245459107076
# At Random Stat 18, the testing accuracy is:0.493562418777848
#
#
# At Random Stat 19, the training accuracy is:0.5030381186505923
# At Random Stat 19, the testing accuracy is:0.49045293470730744
#
#
# At Random Stat 20, the training accuracy is:0.49834152370875284
# At Random Stat 20, the testing accuracy is:0.508436105294171
#
#
# At Random Stat 21, the training accuracy is:0.49812124617728415
# At Random Stat 21, the testing accuracy is:0.510386436699505
#
#
# At Random Stat 22, the training accuracy is:0.5032329563721436
# At Random Stat 22, the testing accuracy is:0.48981341271217993
#
#
# At Random Stat 23, the training accuracy is:0.5022620891077471
# At Random Stat 23, the testing accuracy is:0.49271326441054974
#
#
# At Random Stat 24, the training accuracy is:0.5046523900460473
# At Random Stat 24, the testing accuracy is:0.48224094092206493
#
#
# At Random Stat 25, the training accuracy is:0.5039413919640714
# At Random Stat 25, the testing accuracy is:0.48705925049852483
#
#
# At Random Stat 26, the training accuracy is:0.4975599671230371
# At Random Stat 26, the testing accuracy is:0.5111932148950913
#
#
# At Random Stat 27, the training accuracy is:0.5032107303981332
# At Random Stat 27, the testing accuracy is:0.4895433980993229
#
#
# At Random Stat 28, the training accuracy is:0.49685405162277896
# At Random Stat 28, the testing accuracy is:0.5142293767114285
#
#
# At Random Stat 29, the training accuracy is:0.5030270850675597
# At Random Stat 29, the testing accuracy is:0.48980307152164126
#
#
# At Random Stat 30, the training accuracy is:0.5039404568789096
# At Random Stat 30, the testing accuracy is:0.4874064952773435
#
#
# At Random Stat 31, the training accuracy is:0.4967277218268793
# At Random Stat 31, the testing accuracy is:0.5153758338720833
#
#
# At Random Stat 32, the training accuracy is:0.5015006174405804
# At Random Stat 32, the testing accuracy is:0.4960375118764945
#
#
# At Random Stat 33, the training accuracy is:0.5012327309810047
# At Random Stat 33, the testing accuracy is:0.4965031552530881
#
#
# At Random Stat 34, the training accuracy is:0.5022839112620852
# At Random Stat 34, the testing accuracy is:0.49238460070263457
#
#
# At Random Stat 35, the training accuracy is:0.5031662574577747
# At Random Stat 35, the testing accuracy is:0.48977460725095656
#
#
# At Random Stat 36, the training accuracy is:0.505558985624373
# At Random Stat 36, the testing accuracy is:0.47690617586933515
#
#
# At Random Stat 37, the training accuracy is:0.5085297828088844
# At Random Stat 37, the testing accuracy is:0.466268253523191
#
#
# At Random Stat 38, the training accuracy is:0.5079714915111633
# At Random Stat 38, the testing accuracy is:0.4700481439828268
#
#
# At Random Stat 39, the training accuracy is:0.4962610805079497
# At Random Stat 39, the testing accuracy is:0.5161398934025527
#
#
# At Random Stat 40, the training accuracy is:0.4983120609125642
# At Random Stat 40, the testing accuracy is:0.5078285082725535
#
#
# At Random Stat 41, the training accuracy is:0.5092198877143125
# At Random Stat 41, the testing accuracy is:0.4667043990321965
#
#
# At Random Stat 42, the training accuracy is:0.4960714472732658
# At Random Stat 42, the testing accuracy is:0.5178562582671552
#
#
# At Random Stat 43, the training accuracy is:0.5032469783173794
# At Random Stat 43, the testing accuracy is:0.4877340754171361
#
#
# At Random Stat 44, the training accuracy is:0.49871195819595204
# At Random Stat 44, the testing accuracy is:0.5074726703509105
#
#
# At Random Stat 45, the training accuracy is:0.5003340078768999
# At Random Stat 45, the testing accuracy is:0.5006746425784327
#
#
# At Random Stat 46, the training accuracy is:0.5025648579321994
# At Random Stat 46, the testing accuracy is:0.49150365105958216
#
#
# At Random Stat 47, the training accuracy is:0.5025521825252179
# At Random Stat 47, the testing accuracy is:0.49205345615916063
#
#
# At Random Stat 48, the training accuracy is:0.5012914072339475
# At Random Stat 48, the testing accuracy is:0.49725672830014844
#
#
# At Random Stat 49, the training accuracy is:0.4980752315616557
# At Random Stat 49, the testing accuracy is:0.5091064267085701
#
#
# At Random Stat 50, the training accuracy is:0.49988018281445923
# At Random Stat 50, the testing accuracy is:0.5029399518673845
#
#
# At Random Stat 51, the training accuracy is:0.507501741555997
# At Random Stat 51, the testing accuracy is:0.4710005440830226
#
#
# At Random Stat 52, the training accuracy is:0.5017555942556802
# At Random Stat 52, the testing accuracy is:0.49476186781078446
#
#
# At Random Stat 53, the training accuracy is:0.4992405624898639
# At Random Stat 53, the testing accuracy is:0.5051785305763719
#
#
# At Random Stat 54, the training accuracy is:0.4965636742352405
# At Random Stat 54, the testing accuracy is:0.5140742984293154
#
#
# At Random Stat 55, the training accuracy is:0.5024069212052469
# At Random Stat 55, the testing accuracy is:0.4926084124681992
#
#
# At Random Stat 56, the training accuracy is:0.5079313519372557
# At Random Stat 56, the testing accuracy is:0.47239862043068614
#
#
# At Random Stat 57, the training accuracy is:0.5020586017208459
# At Random Stat 57, the testing accuracy is:0.4934674014064998
#
#
# At Random Stat 58, the training accuracy is:0.5032718006442477
# At Random Stat 58, the testing accuracy is:0.4876986496562463
#
#
# At Random Stat 59, the training accuracy is:0.502947472416436
# At Random Stat 59, the testing accuracy is:0.489525706899288
#
#
# At Random Stat 60, the training accuracy is:0.499239982460966
# At Random Stat 60, the testing accuracy is:0.5048477092248917
#
#
# At Random Stat 61, the training accuracy is:0.505757643965254
# At Random Stat 61, the testing accuracy is:0.47813610976546816
#
#
# At Random Stat 62, the training accuracy is:0.49404508609331477
# At Random Stat 62, the testing accuracy is:0.5256022793780826
#
#
# At Random Stat 63, the training accuracy is:0.49452575603774807
# At Random Stat 63, the testing accuracy is:0.5250928837875257
#
#
# At Random Stat 64, the training accuracy is:0.505407029619815
# At Random Stat 64, the testing accuracy is:0.4803307697419936
#
#
# At Random Stat 65, the training accuracy is:0.49968799836402134
# At Random Stat 65, the testing accuracy is:0.5029227064812016
#
#
# At Random Stat 66, the training accuracy is:0.5017582274512244
# At Random Stat 66, the testing accuracy is:0.4955909416004828
#
#
# At Random Stat 67, the training accuracy is:0.4993429107196482
# At Random Stat 67, the testing accuracy is:0.5044428139281705
#
#
# At Random Stat 68, the training accuracy is:0.4985993277712202
# At Random Stat 68, the testing accuracy is:0.5071516742281765
#
#
# At Random Stat 69, the training accuracy is:0.5006080066773692
# At Random Stat 69, the testing accuracy is:0.4995460807819109
#
#
# At Random Stat 70, the training accuracy is:0.49762873972380406
# At Random Stat 70, the testing accuracy is:0.5113041648312926
#
#
# At Random Stat 71, the training accuracy is:0.5007070179846818
# At Random Stat 71, the testing accuracy is:0.4988767270772143
#
#
# At Random Stat 72, the training accuracy is:0.49712866950392065
# At Random Stat 72, the testing accuracy is:0.5137362910859409
#
#
# At Random Stat 73, the training accuracy is:0.5023362305460681
# At Random Stat 73, the testing accuracy is:0.4925369345050895
#
#
# At Random Stat 74, the training accuracy is:0.505833824731916
# At Random Stat 74, the testing accuracy is:0.4773768911663159
#
#
# At Random Stat 75, the training accuracy is:0.49918896802666013
# At Random Stat 75, the testing accuracy is:0.5052772330676951
#
#
# At Random Stat 76, the training accuracy is:0.49481117278219067
# At Random Stat 76, the testing accuracy is:0.5233033089189019
#
#
# At Random Stat 77, the training accuracy is:0.5019604039488743
# At Random Stat 77, the testing accuracy is:0.49414816330352196
#
#
# At Random Stat 78, the training accuracy is:0.5035422314015808
# At Random Stat 78, the testing accuracy is:0.4878496324463548
#
#
# At Random Stat 79, the training accuracy is:0.4965533307868396
# At Random Stat 79, the testing accuracy is:0.5150609548600351
#
#
# At Random Stat 80, the training accuracy is:0.49645176489355847
# At Random Stat 80, the testing accuracy is:0.5164864315348727
#
#
# At Random Stat 81, the training accuracy is:0.500963095444662
# At Random Stat 81, the testing accuracy is:0.49871276018049704
#
#
# At Random Stat 82, the training accuracy is:0.49852283453449076
# At Random Stat 82, the testing accuracy is:0.5075644072544658
#
#
# At Random Stat 83, the training accuracy is:0.5021078563929579
# At Random Stat 83, the testing accuracy is:0.492981489555546
#
#
# At Random Stat 84, the training accuracy is:0.5011162473697229
# At Random Stat 84, the testing accuracy is:0.4970545449955778
#
#
# At Random Stat 85, the training accuracy is:0.5004686350508631
# At Random Stat 85, the testing accuracy is:0.5000139709403428
#
#
# At Random Stat 86, the training accuracy is:0.5013271047822928
# At Random Stat 86, the testing accuracy is:0.4968291780280679
#
#
# At Random Stat 87, the training accuracy is:0.5032143228764931
# At Random Stat 87, the testing accuracy is:0.4888879107486481
#
#
# At Random Stat 88, the training accuracy is:0.49760126521014225
# At Random Stat 88, the testing accuracy is:0.5116571837907555
#
#
# At Random Stat 89, the training accuracy is:0.4950838722647891
# At Random Stat 89, the testing accuracy is:0.5217518427673926
#
#
# At Random Stat 90, the training accuracy is:0.5090503933496224
# At Random Stat 90, the testing accuracy is:0.46206368669861275
#
#
# At Random Stat 91, the training accuracy is:0.5081804125993548
# At Random Stat 91, the testing accuracy is:0.4684536539198835
#
#
# At Random Stat 92, the training accuracy is:0.49864918527291713
# At Random Stat 92, the testing accuracy is:0.5067805212642926
#
#
# At Random Stat 93, the training accuracy is:0.49985229830734124
# At Random Stat 93, the testing accuracy is:0.5023949936746288
#
#
# At Random Stat 94, the training accuracy is:0.49950733821321147
# At Random Stat 94, the testing accuracy is:0.5020016857451064
#
#
# At Random Stat 95, the training accuracy is:0.4993713839063265
# At Random Stat 95, the testing accuracy is:0.5049253961120173
#
#
# At Random Stat 96, the training accuracy is:0.5041132673697019
# At Random Stat 96, the testing accuracy is:0.4824618032352056
#
#
# At Random Stat 97, the training accuracy is:0.49996475914051086
# At Random Stat 97, the testing accuracy is:0.501060649335144
#
#
# At Random Stat 98, the training accuracy is:0.5062277678160698
# At Random Stat 98, the testing accuracy is:0.4753218201196163
#
#
# At Random Stat 99, the training accuracy is:0.4952558921517932
# At Random Stat 99, the testing accuracy is:0.5190767247203616

# %% [markdown]
# At Random Stat 85, the training accuracy is:0.5004686350508631
#
# At Random Stat 85, the testing accuracy is:0.5000139709403428
#
# At Random Stat 85 we are getting very less diffrence in training and testing accuracy.

# %%
x_train_b, x_test_b, y_train_b, y_test_b= train_test_split(x,y, test_size=0.20, random_state= 85)

# %%
lr.fit(x_train_b,y_train_b)
pred_test=lr.predict(x_test_b)

print(r2_score(y_test_b,pred_test))
# Out:
# 0.5000139709403428

# %% [markdown]
# linear Regression giving model accuracy = 0.5018597031049953 percent.
#
# In next step we will perform cross validation of the model.

# %% [markdown]
# # Cross Validation of Model

# %%
test_accuracy= r2_score(y_test_b,pred_test)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"At cross fold {i} the Cross Val score is {cv_mean*100} and Accuracy score is {test_accuracy*100}")
# Out:
# At cross fold 2 the Cross Val score is 49.85839933456386 and Accuracy score is 50.00139709403428
# At cross fold 3 the Cross Val score is 49.886620473968094 and Accuracy score is 50.00139709403428
# At cross fold 4 the Cross Val score is 49.77064254735985 and Accuracy score is 50.00139709403428
# At cross fold 5 the Cross Val score is 49.859470500016734 and Accuracy score is 50.00139709403428
# At cross fold 6 the Cross Val score is 49.81515778845551 and Accuracy score is 50.00139709403428
# At cross fold 7 the Cross Val score is 49.90844095599331 and Accuracy score is 50.00139709403428
# At cross fold 8 the Cross Val score is 49.83799464632808 and Accuracy score is 50.00139709403428
# At cross fold 9 the Cross Val score is 49.85310773677154 and Accuracy score is 50.00139709403428

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,pred_test))
print('Mean Squared Error:', mean_squared_error(y_test_b,pred_test))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,pred_test)))
# Out:
# Error:
# Mean Absolute Error: 902.7230407576787
# Mean Squared Error: 1470310.6740625678
# Root Mean Square Error: 1212.563678353664

# %% [markdown]
# At cross fold 7 the Cross fold 7 the Cross Val score is 49.90844095599331 and Accuracy score is 50.00139709403428

# %% [markdown]
# Model accuracy is not good, we can use regularization to find best results, lets check.

# %% [markdown]
# # 2. Lasso

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

parameters= {'alpha':[0.0001,0.001,0.01,0.1,1,10], 'random_state': list(range(0,10)), 'selection':['cyclic', 'random'], 'max_iter':[500,1000,1200,1500,2000]}
ls=Lasso()
clf=GridSearchCV(ls, parameters)
clf.fit(x_train_b, y_train_b)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'max_iter': 500, 'random_state': 4, 'selection': 'random'}

# %%
ls=Lasso(alpha=1,max_iter=500, random_state=4, selection='random')
ls.fit(x_train_b, y_train_b)
ls.score(x_train_b, y_train_b)
ls_pred=ls.predict(x_test_b)

lsd=r2_score(y_test_b, ls_pred)
print('R2 score:', lsd*100)

rdscore= cross_val_score(ls,x,y,cv=7)
lsc=rdscore.mean()
print('Cross val Score :', lsc*100)
# Out:
# R2 score: 50.009224035701706
# Cross val Score : 49.91154530747525

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,ls_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,ls_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,ls_pred)))
# Out:
# Error:
# Mean Absolute Error: 918.0201472275465
# Mean Squared Error: 1520705.573771762
# Root Mean Square Error: 1233.1689153444315

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= ls_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# Accuracy is same as liner Regression , errors also same. Lets check for Ridge regularization.

# %% [markdown]
# # 3. Ridge

# %%
parameters= {'alpha':[0.0001,0.001,0.01,0.1,1,10], 'fit_intercept': [True,False], 'normalize':[True, False], 'copy_X': [True , False], 'tol':[0.0001,0.001,0.01,0.1,1,10]}
rd=Ridge()
rdclf=GridSearchCV(rd, parameters)
rdclf.fit(x_train_b, y_train_b)
print(rdclf.best_params_)
# Out:
# {'alpha': 10, 'copy_X': True, 'fit_intercept': True, 'normalize': False, 'tol': 0.0001}

# %%
rd= Ridge(alpha= 10, copy_X= True, fit_intercept= True, normalize= False, tol= 0.0001)
rd.fit(x_train_b, y_train_b)
rd.score(x_train_b, y_train_b)
rd_pred= rd.predict(x_test_b)

rds=r2_score(y_test_b, rd_pred)
print('r2 score: ', rds*100)

rdcvscore= cross_val_score(rd,x,y,cv=7)
rdcv=rdcvscore.mean()
print('Cross val Score', rdcv*100)
# Out:
# r2 score:  49.99837447963193
# Cross val Score 49.90881851050084

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,rd_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,rd_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,rd_pred)))
# Out:
# Error:
# Mean Absolute Error: 918.0898866374473
# Mean Squared Error: 1521035.6142656333
# Root Mean Square Error: 1233.3027261243012

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= rd_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# r2 score:  49.99837447963193
# Cross val Score 49.90881851050084
# Both the score are almost same, we can consider this model, But lets try DecisionTreeRegressor.

# %% [markdown]
# # 3.DecisionTreeRegressor

# %%
parameters={'criterion':['mse','friedman_mse', 'mae', 'poisson'], 'splitter':['best', 'random'],'max_depth':[4,5,6,7,8,9,10,11,12,15,20,30,40,50,70,90,120,150]}
dt=DecisionTreeRegressor()
dtclf= GridSearchCV(dt, parameters )
dtclf.fit(x_train_b, y_train_b)
print(dtclf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'max_depth': 5, 'splitter': 'best'}

# %%
dt=DecisionTreeRegressor(criterion='friedman_mse', splitter='best', max_depth =5)
dt.fit(x_train_b, y_train_b)
dt.score(x_train_b, y_train_b)
dt_pred=dt.predict(x_test_b)

dt_score=r2_score(y_test_b, dt_pred)
print('R2 Score:', dt_score*100)

dtcvscore=cross_val_score(dt,x,y,cv=7)
dtcv=dtcvscore.mean()
print('Cross Val Score:', dtcv*100)
# Out:
# R2 Score: 60.30475831318166
# Cross Val Score: 59.15213059012068

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,dt_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,dt_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,dt_pred)))
# Out:
# Error:
# Mean Absolute Error: 772.9631555597402
# Mean Squared Error: 1207518.269539811
# Root Mean Square Error: 1098.871361688806

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= dt_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# R2 Score: 60.30475831318166
# Cross Val Score: 59.15213059012068
#
# There is diffrence in Cv score  model abd R2 score. lets check for anaother Model.

# %% [markdown]
# # 4. KNeighborsRegressor

# %%
parameters={'n_neighbors':[1,2,3,5,6,7,8,9,10,15],'weights':['uniform', 'distance'], 'algorithm':['auto','ball_tree','kd_tree'],'leaf_size':[10,20,30,40,50] }
kn=KNeighborsRegressor()
knclf=GridSearchCV(kn,parameters)
knclf.fit(x_train_b, y_train_b)
print(knclf.best_params_)
# Out:
# {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 15, 'weights': 'uniform'}

# %%
kn=KNeighborsRegressor(algorithm='auto', n_neighbors=15, weights='uniform', leaf_size=10)
kn.fit(x_train_b, y_train_b)
kn.score(x_train_b,y_train_b)
kn_pred=kn.predict(x_test_b)

kn_score= r2_score(y_test_b, kn_pred)
print('R2 Score: 0', kn_score*100)

kn_cvscore=cross_val_score(kn,x,y, cv=7)
cv_mean=kn_cvscore.mean()
print('Cross val Score :',cv_mean*100 )
# Out:
# R2 Score: 0 55.53107064761913
# Cross val Score : 55.35715688024398

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,kn_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,kn_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,kn_pred)))
# Out:
# Error:
# Mean Absolute Error: 825.564873368524
# Mean Squared Error: 1352732.5275791509
# Root Mean Square Error: 1163.0703020794363

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= kn_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# R2 Score: 0 55.53107064761913
# Cross val Score : 55.35715688024398
#
# R2score and Cross_val_score are almost same , we can consider this model. it is giving good accuracy over DecisionTreeRegressor.

# %% [markdown]
# # 5. Ensemble Techniques

# %%
parameters={'criterion':['mse', 'mae'],'max_features':['auto', 'sqrt', 'log2'],'n_estimators':[50,75,100,125,150,175]}
rf=RandomForestRegressor()
rfclf=GridSearchCV(rf, parameters)
rfclf.fit(x_train_b, y_train_b)
print(rfclf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2', 'n_estimators': 175}

# %%
rf=RandomForestRegressor(criterion='mae', max_features='log2', n_estimators=175)
rf.fit(x_train_b, y_train_b)
rf.score(x_train_b,y_train_b)
rf_pred=rf.predict(x_test_b)

rf_score= r2_score(y_test_b, rf_pred)
print('R2 score:', rf_score*100)

rfcv=cross_val_score(rf,x,y, cv=7)
rfcvscore=rfcv.mean()
print('Cross val Score :',rfcvscore*100 )
# Out:
# R2 score: 58.52539946563129
# Cross val Score : 56.935426406141346

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,rf_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,rf_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,rf_pred)))
# Out:
# Error:
# Mean Absolute Error: 781.7474114969418
# Mean Squared Error: 1261645.8733830159
# Root Mean Square Error: 1123.2301070497601

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= rf_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# R2 score: 58.52539946563129
# Cross val Score : 56.935426406141346
# We cannot consider this model as both score having huge diffrence.

# %% [markdown]
# # 6.GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
parameters={'loss':['ls', 'lad', 'huber', 'quantile'],'criterion':['friedman_mse', 'mse', 'mae'], 'learning_rate':[0.001,0.01,0.1,1]}
gb=GradientBoostingRegressor()
gbclf=GridSearchCV(gb, parameters)
gbclf.fit(x_train_b, y_train_b)
print(gbclf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'learning_rate': 0.1, 'loss': 'lad'}

# %%
gb=GradientBoostingRegressor(criterion='friedman_mse', loss='lad',learning_rate=0.1)
gb.fit(x_train_b, y_train_b)
gb.score(x_train_b,y_train_b)
gb_pred=rf.predict(x_test_b)

gb_score= r2_score(y_test_b, rf_pred)
print('R2 score:', gb_score*100)

gbcv=cross_val_score(gb,x,y, cv=7)
gbcvscore=gbcv.mean()
print('Cross val Score :',gbcvscore*100 )
# Out:
# R2 score: 58.52539946563129
# Cross val Score : 59.554382473876736

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,gb_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,gb_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,gb_pred)))
# Out:
# Error:
# Mean Absolute Error: 781.7474114969418
# Mean Squared Error: 1261645.8733830159
# Root Mean Square Error: 1123.2301070497601

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= gb_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# R2 score: 58.52539946563129
# Cross val Score : 59.554382473876736
#
# Both the score having considerable diffrence so we cannot select GradientBoostingRegressor as our best model.

# %% [markdown]
# # We can see KNeighborsRegressor Having good very less diffrence in R2 score and Cross Val Score. we can consider this our best model.

# %% [markdown]
# ### Saving Best Model

# %%
import pickle
filename='Big_Mart_Sales_Prediction.pkl'
pickle.dump(kn,open(filename,'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
prediction=loaded_model.predict(test)

# %%
print(prediction)
# Out:
# [3515.95664    4089.83185333 3293.75698667 ... 3730.52178667 4222.59237333
#  3533.53376   ]

# %%
predicted= pd.DataFrame(data=prediction)

predicted.to_csv('prediction.csv',index=False)
